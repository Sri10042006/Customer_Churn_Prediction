# %%
import pandas as pd
data=pd.read_csv("/content/customer_churn_dataset-training-master.csv")
df=pd.DataFrame(data)
print(df.head())
print(df.shape)
print(df.dtypes)
print(df.select_dtypes(include="number").columns.tolist())
print(df.select_dtypes(include=["object","category"]).columns.tolist())
df.isnull()
print(df.isnull().sum())
target_cols = ["CustomerID", "Age", "Gender", "Tenure", "Usage Frequency", "Support Calls", "Payment Delay", "Subscription Type", "Contract Length", "Total Spend", "Last Interaction", "Churn"]

df[target_cols] = df[target_cols].fillna(df[target_cols].mean(numeric_only=True))
print(df)
print(df.info())
print(df.describe())
